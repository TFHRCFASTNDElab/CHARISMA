# %%
'Please Enter your DOT Email address.'
user_email_address = 'your.name@dot.gov'

# %%
import json

# Revise the directory path. We recommend to create git_clone under your Workspace directory. 
# Modify the 'paths' dictionary if you want to create under nested directory in Workspace.

# Define paths
paths = {
    "Requirement_path": f'/Workspace/Users/{user_email_address}/CHARISMA/environment/requirements.txt',
    "Code_path": f'/Workspace/Users/{user_email_address}/CHARISMA/ground-penetrating-radar/Rebar mapping/code/',
    "Data_path": f'/Workspace/Users/{user_email_address}/CHARISMA/ground-penetrating-radar/Rebar mapping/data/'
}

# Save paths to a JSON file
with open('paths.json', 'w') as f:
    json.dump(paths, f)

# %%
# Install CHARISMA
# %pip install -r "{paths['Requirement_path']}"

# Restart Kernel
dbutils.library.restartPython()
# Out:
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Collecting pandas==2.2.0 (from -r /Workspace/Users/steve.yang.ctr@dot.gov/CHARISMA/environment/requirements.txt (line 4))
#   Using cached pandas-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting numpy==1.24.3 (from -r /Workspace/Users/steve.yang.ctr@dot.gov/CHARISMA/environment/requirements.txt (line 5))
#   Using cached numpy-1.24.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting scikit-learn==1.1.3 (from -r /Workspace/Users/steve.yang.ctr@dot.gov/CHARISMA/environment/requirements.txt (line 6))
#   Using cached scikit_learn-1.1.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting scipy==1.12.0 (from -r /Workspace/Users/steve.yang.ctr@dot.gov/CHARISMA/environment/requirements.txt (line 7))
#   Using cached scipy-1.12.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting matplotlib==3.8.2 (from -r /Workspace/Users/steve.yang.ctr@dot.gov/CHARISMA/environment/requirements.txt (line 8))
#   Using cached matplotlib-3.8.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting tqdm==4.64.1 (from -r /Workspace/Users/steve.yang.ctr@dot.gov/CHARISMA/environment/requirements.txt (line 9))
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl.metadata (57 kB)
# Collecting threadpoolctl==3.1.0 (from -r /Workspace/Users/steve.yang.ctr@dot.gov/CHARISMA/environment/requirements.txt (line 10))
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /databricks/python3/lib/python3.11/site-packages (from pandas==2.2.0->-r /Workspace/Users/steve.yang.ctr@dot.gov/CHARISMA/environment/requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.11/site-packages (from pandas==2.2.0->-r /Workspace/Users/steve.yang.ctr@dot.gov/CHARISMA/environment/requirements.txt (line 4)) (2022.7)
# Collecting tzdata>=2022.7 (from pandas==2.2.0->-r /Workspace/Users/steve.yang.ctr@dot.gov/CHARISMA/environment/requirements.txt (line 4))
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: joblib>=1.0.0 in /databricks/python3/lib/python3.11/site-packages (from scikit-learn==1.1.3->-r /Workspace/Users/steve.yang.ctr@dot.gov/CHARISMA/environment/requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /databricks/python3/lib/python3.11/site-packages (from matplotlib==3.8.2->-r /Workspace/Users/steve.yang.ctr@dot.gov/CHARISMA/environment/requirements.txt (line 8)) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.11/site-packages (from matplotlib==3.8.2->-r /Workspace/Users/steve.yang.ctr@dot.gov/CHARISMA/environment/requirements.txt (line 8)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /databricks/python3/lib/python3.11/site-packages (from matplotlib==3.8.2->-r /Workspace/Users/steve.yang.ctr@dot.gov/CHARISMA/environment/requirements.txt (line 8)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /databricks/python3/lib/python3.11/site-packages (from matplotlib==3.8.2->-r /Workspace/Users/steve.yang.ctr@dot.gov/CHARISMA/environment/requirements.txt (line 8)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /databricks/python3/lib/python3.11/site-packages (from matplotlib==3.8.2->-r /Workspace/Users/steve.yang.ctr@dot.gov/CHARISMA/environment/requirements.txt (line 8)) (23.2)
# Requirement already satisfied: pillow>=8 in /databricks/python3/lib/python3.11/site-packages (from matplotlib==3.8.2->-r /Workspace/Users/steve.yang.ctr@dot.gov/CHARISMA/environment/requirements.txt (line 8)) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /databricks/python3/lib/python3.11/site-packages (from matplotlib==3.8.2->-r /Workspace/Users/steve.yang.ctr@dot.gov/CHARISMA/environment/requirements.txt (line 8)) (3.0.9)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas==2.2.0->-r /Workspace/Users/steve.yang.ctr@dot.gov/CHARISMA/environment/requirements.txt (line 4)) (1.16.0)
# Using cached pandas-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
# Using cached numpy-1.24.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Using cached scikit_learn-1.1.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (32.0 MB)
# Using cached scipy-1.12.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.4 MB)
# Using cached matplotlib-3.8.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
# Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Installing collected packages: tzdata, tqdm, threadpoolctl, numpy, scipy, pandas, scikit-learn, matplotlib
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2022.1
#     Not uninstalling tzdata at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-bb7e626e-8705-4a7d-bfc7-bbd72b5c36a3
#     Can't uninstall 'tzdata'. No files were found to uninstall.
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.0
#     Not uninstalling tqdm at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-bb7e626e-8705-4a7d-bfc7-bbd72b5c36a3
#     Can't uninstall 'tqdm'. No files were found to uninstall.
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 2.2.0
#     Not uninstalling threadpoolctl at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-bb7e626e-8705-4a7d-bfc7-bbd72b5c36a3
#     Can't uninstall 'threadpoolctl'. No files were found to uninstall.
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Not uninstalling numpy at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-bb7e626e-8705-4a7d-bfc7-bbd72b5c36a3
#     Can't uninstall 'numpy'. No files were found to uninstall.
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.1
#     Not uninstalling scipy at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-bb7e626e-8705-4a7d-bfc7-bbd72b5c36a3
#     Can't uninstall 'scipy'. No files were found to uninstall.
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Not uninstalling pandas at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-bb7e626e-8705-4a7d-bfc7-bbd72b5c36a3
#     Can't uninstall 'pandas'. No files were found to uninstall.
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.0
#     Not uninstalling scikit-learn at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-bb7e626e-8705-4a7d-bfc7-bbd72b5c36a3
#     Can't uninstall 'scikit-learn'. No files were found to uninstall.
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.2
#     Not uninstalling matplotlib at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-bb7e626e-8705-4a7d-bfc7-bbd72b5c36a3
#     Can't uninstall 'matplotlib'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# databricks-feature-engineering 0.3.0 requires pyspark<4,>=3.1.2, which is not installed.
# petastorm 0.12.1 requires pyspark>=2.1.0, which is not installed.
# tensorboard 2.15.1 requires protobuf<4.24,>=3.19.6, but you have protobuf 4.24.1 which is incompatible.
# ydata-profiling 4.5.1 requires numpy<1.24,>=1.16.0, but you have numpy 1.24.3 which is incompatible.
# ydata-profiling 4.5.1 requires pandas!=1.4.0,<2.1,>1.1, but you have pandas 2.2.0 which is incompatible.
# ydata-profiling 4.5.1 requires scipy<1.12,>=1.4.1, but you have scipy 1.12.0 which is incompatible.
# Successfully installed matplotlib-3.8.2 numpy-1.24.3 pandas-2.2.0 scikit-learn-1.1.3 scipy-1.12.0 threadpoolctl-3.1.0 tqdm-4.64.1 tzdata-2024.1
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.

# %%
# Since we restarted kernel
import json

# Load paths from the JSON file
with open('paths.json', 'r') as f:
    paths = json.load(f)

# Retrieve individual paths
Code_path = paths["Code_path"]
Data_path = paths["Data_path"]

# %%
import sys 
sys.path.append(Code_path)
import GPR_locate_rebars as gpr_lr

# %%
# Save DZT into CSV files
downloaded_path = Data_path
df1, df2 = gpr_lr.readdzt(downloaded_path + "Mississippi_bridge_data.DZT")
gpr_lr.save_to_csv(df1, downloaded_path, 'data')
gpr_lr.save_to_csv(df2, downloaded_path, 'config', True, True)

# %%
# Read saved CSV file
user_directory = Data_path
df_1, df_2 = gpr_lr.read_csv(user_directory)

# %%
# Allocate all the GPR configuration settings as variables in Python
result_variables = gpr_lr.config_to_variable(df_2)
locals().update(result_variables)

# %%
# Outlier removal through IQR
IQR_df_1 = gpr_lr.Interquartile_Range(df_1, min_value=0.10, max_value=0.95, multiplier=1.5)

# %%
# Split the DataFrame (too long column)
clipped_df_chunk=gpr_lr.data_chunk(IQR_df_1)

# %%
# Plot A-scans and B-scan of the data (Outlier removed & coulmn cut)
gpr_lr.plot.Plot_a_scan(clipped_df_chunk[0])
gpr_lr.plot.Plot_b_scan_advanced(clipped_df_chunk[0], 0.7)

# %%
# Apply power gain 
gpr_data_powered = gpr_lr.gain(clipped_df_chunk[0], type="pow", alpha=0.4, t0=120)

# %%
# Plot A-scans and B-scan of the data after gain
gpr_lr.plot.Plot_a_scan(gpr_data_powered)
gpr_lr.plot.Plot_b_scan_advanced(gpr_data_powered, 0.7)

# %%
# Apply trinomial dewow function
dewowed_ar = gpr_lr.dewow(gpr_data_powered)

# %%
# Plot A-scans and B-scan of the data after dewow
gpr_lr.plot.Plot_a_scan(dewowed_ar)
gpr_lr.plot.Plot_b_scan_advanced(dewowed_ar, 0.7)

# %%
# Apply scan-by-scan time-zero correction
time0df, rh_nsamp = gpr_lr.Timezero_individual(dewowed_ar, rhf_position, rhf_range)

# %%
# Plot A-scans and B-scan of the time-zeroed data
gpr_lr.plot.Plot_a_scan(time0df)
gpr_lr.plot.Plot_b_scan_advanced(time0df, 0.7)

# %%
# Migration
migrated_df, profilePos, dt, dx, velocity = gpr_lr.FK_migration(time0df, rhf_spm, rhf_sps, rhf_range, rh_nsamp, rhf_espr=11)
# Out:
# 512it [00:00, 5764.96it/s]

# %%
# Plot migrated data
gpr_lr.plot.Plot_migrated_advanced(migrated_df, profilePos, velocity, rhf_range, rh_nsamp, 0.7)

# %%
# Locate rebar configuration based on the migration result
gpr_lr.locate_rebar_consecutive(migrated_df, velocity, rhf_range, rh_nsamp, profilePos, vmin=0.15, vmax=0.6, amplitude_threshold=0.53, depth_threshold=8, minimal_y_index=90, num_clusters=11, random_state=42, redundancy_filter=0.6)
# Out:
# Uploading artifacts:   0%|          | 0/5 [00:00<?, ?it/s]
# array([[134.51609671,   5.28002529],
#        [ 28.3591274 ,   5.26316447],
#        [106.42378881,   5.09150894],
#        [ 38.93325607,   7.63941901],
#        [ 92.28781687,   7.64746655],
#        [ 53.49902427,   5.01821881],
#        [ 79.42893329,   4.9606057 ],
#        [  4.75427628,   5.78560965],
#        [ 16.5831929 ,   7.60326069],
#        [120.99175991,   7.79462165],
#        [ 64.55987189,   7.91533482]])
